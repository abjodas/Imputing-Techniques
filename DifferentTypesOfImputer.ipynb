# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np
import random
from math import sqrt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error

df = fetch_california_housing()
df = pd.DataFrame(df.data)

# %%
df.head()
# Out:
#         0     1         2         3       4         5      6       7
# 0  8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1  8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2  7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3  5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4  3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25

# %%
cal = fetch_california_housing()
train, target = pd.DataFrame(cal.data), pd.DataFrame(cal.target)

# %%
train.columns = ['zero' ,'one', 'two', 'three', 'four', 'five', 'six', 'seven']
train.insert(loc = (len(train.columns)), value = target, column = 'Target')
train.head()
# Out:
#      zero   one       two     three    four      five    six   seven  Target
# 0  8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23   4.526
# 1  8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22   3.585
# 2  7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24   3.521
# 3  5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25   3.413
# 4  3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25   3.422

# %%
column = train['zero']
missing_pct = int(column.size * 0.4)
i = [random.choice(range(column.shape[0])) for _ in range(missing_pct)]
column[i] = np.NaN
train
# Out:
#          zero   one       two     three    four      five    six   seven  \
# 0      8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2         NaN  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4      3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# ...       ...   ...       ...       ...     ...       ...    ...     ...
# 20635  1.5603  25.0  5.045455  1.133333   845.0  2.560606  39.48 -121.09
# 20636     NaN  18.0  6.114035  1.315789   356.0  3.122807  39.49 -121.21
# 20637  1.7000  17.0  5.205543  1.120092  1007.0  2.325635  39.43 -121.22
# 20638  1.8672  18.0  5.329513  1.171920   741.0  2.123209  39.43 -121.32
# 20639     NaN  16.0  5.254717  1.162264  1387.0  2.616981  39.37 -121.24
#
#        Target
# 0       4.526
# 1       3.585
# 2       3.521
# 3       3.413
# ...

# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install missingpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.3 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.2
#     Uninstalling pip-23.3.2:
#       Successfully uninstalled pip-23.3.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 8.2 MB/s eta 0:00:00
# ...

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors = 2, weights = 'uniform')
train[['zero']] = imputer.fit_transform(train[['zero']])

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values = np.NaN, strategy = 'mean')
imputer = imputer.fit(train[['zero']])
train['zero'] = imputer.transform(train[['zero']]).ravel()

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imputer = IterativeImputer(max_iter = 10, random_state = 45)
train[['zero']] = imputer.fit_transform(train[['zero']])
train
# Out:
#            zero   one       two     three    four      five    six   seven  \
# 0      8.325200  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.301400  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2      3.867173  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      5.643100  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4      3.846200  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# ...         ...   ...       ...       ...     ...       ...    ...     ...
# 20635  1.560300  25.0  5.045455  1.133333   845.0  2.560606  39.48 -121.09
# 20636  3.867173  18.0  6.114035  1.315789   356.0  3.122807  39.49 -121.21
# 20637  1.700000  17.0  5.205543  1.120092  1007.0  2.325635  39.43 -121.22
# 20638  1.867200  18.0  5.329513  1.171920   741.0  2.123209  39.43 -121.32
# 20639  3.867173  16.0  5.254717  1.162264  1387.0  2.616981  39.37 -121.24
#
#        Target
# 0       4.526
# 1       3.585
# 2       3.521
# ...

# %%
train
# Out:
#            zero   one       two     three    four      five    six   seven  \
# 0      8.325200  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.301400  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2      7.257400  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      5.643100  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4      3.856435  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# ...         ...   ...       ...       ...     ...       ...    ...     ...
# 20635  1.560300  25.0  5.045455  1.133333   845.0  2.560606  39.48 -121.09
# 20636  2.556800  18.0  6.114035  1.315789   356.0  3.122807  39.49 -121.21
# 20637  1.700000  17.0  5.205543  1.120092  1007.0  2.325635  39.43 -121.22
# 20638  3.856435  18.0  5.329513  1.171920   741.0  2.123209  39.43 -121.32
# 20639  3.856435  16.0  5.254717  1.162264  1387.0  2.616981  39.37 -121.24
#
#        Target
# 0       4.526
# 1       3.585
# 2       3.521
# ...

# %%
imputer = SimpleImputer(strategy = 'median')

train = imputer.fit_transform(train)

# %%
train.dropna(inplace = True)
train.shape
# Out:
# (13801, 9)

# %%
train
# Out:
#            zero   one       two     three    four      five    six   seven  \
# 0      8.325200  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.301400  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2      7.257400  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      3.874432  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4      3.846200  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# ...         ...   ...       ...       ...     ...       ...    ...     ...
# 20635  3.874432  25.0  5.045455  1.133333   845.0  2.560606  39.48 -121.09
# 20636  2.556800  18.0  6.114035  1.315789   356.0  3.122807  39.49 -121.21
# 20637  1.700000  17.0  5.205543  1.120092  1007.0  2.325635  39.43 -121.22
# 20638  3.874432  18.0  5.329513  1.171920   741.0  2.123209  39.43 -121.32
# 20639  2.388600  16.0  5.254717  1.162264  1387.0  2.616981  39.37 -121.24
#
#        Target
# 0       4.526
# 1       3.585
# 2       3.521
# ...

# %%
df.describe()
# Out:
#                   0             1             2             3             4  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#                   5             6             7
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...
